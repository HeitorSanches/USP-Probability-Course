# %% [markdown]
# # Class 1.1

# %%
import random
moeda = ["cara","coroa"]
for i in range(0,10):
    # lança moeda
    saida = random.choice(moeda)
    print(saida)
# Out:
# cara
# cara
# coroa
# cara
# coroa
# coroa
# cara
# cara
# cara
# cara
